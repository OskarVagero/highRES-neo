# %%
import pandas as pd

# %%
#df = pd.read_clipboard(index_col=[0,1,2,3])

# %%
#writefilename = "Transmission_Europe_nodes_2050_snapshot-MW.tsv"
#compression_opts = dict(method='zip',archive_name=writefilename)
#df.to_csv("data/graabak-et-al-2019/processed/" + writefilename + ".zip", sep="\t", compression=compression_opts)

# %%
df = pd.read_csv(
    "data/graabak-et-al-2019/processed/Transmission_Europe_nodes_2050_snapshot-MW.tsv.zip",
    sep = "\t",
    compression = "zip",
    index_col = [0,1,2,3]
)

# %%
df
# Out:
#                                                            [MW]
# to_node_# to_node_country from_node_# from_node_country
# 4         es              25          fr                  16900
# 52        it              25          fr                   5800
# 25        fr              47          ch                   9500
#                           96          ie                   5700
#                           90          uk                  15000
# ...                                                         ...
# 115       ns              79          no                 100000
# 116       ns              88          se                 100000
# 80        no              7981        no                    900
# 8081      no              82          no                   2000
#                           7981        no                   7000
#
# [117 rows x 1 columns]

# %%
df.sort_index().loc[(slice(None), "no", slice(None), slice(None)), :]
# Out:
#                                                           [MW]
# to_node_# to_node_country from_node_# from_node_country
# 79        no              7981        no                 13700
#                           80          no                  5500
#                           92          uk                  5000
# 7981      no              81          no                 13700
#                           93          uk                  1400
# 80        no              7981        no                   900
#                           8081        no                  1500
#                           82          no                  6300
# 8081      no              7981        no                  7000
#                           81          no                     0
#                           82          no                  2000
# 8082      no              81          no                  7000
# 81        no              83          no                  1095
# ...

# %%
df.loc[(slice(None), "no", slice(None), slice(None)), :]
# Out:
#                                                           [MW]
# to_node_# to_node_country from_node_# from_node_country
# 8082      no              81          no                  7000
# 80        no              82          no                  6300
# 81        no              83          no                  1095
# 82        no              83          no                  1100
#                           88          se                  2148
# 83        no              84a         no                  1900
# 84a       no              84b         no                  1100
# 83        no              87b         se                  1000
# 79        no              80          no                  5500
#                           92          uk                  5000
# 7981      no              93          uk                  1400
# 80        no              8081        no                  1500
# 8081      no              81          no                     0
# ...

# %%
df.loc[(3)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Pyconda/miniconda3/envs/atlite/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-04368c8696ba> in <module>
# ...
