# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from shapely.geometry import Polygon, Point

# %%
nuts_to_ssb = {
 'NO081': 'NO03',
 'NO082': 'NO30',
 'NO020': 'NO34',
 'NO091': 'NO38',
 'NO092': 'NO42',
 'NO0A1': 'NO11',
 'NO0A2': 'NO46',
 'NO0A3': 'NO15',
 'NO060': 'NO50',
 'NO071': 'NO18',
 'NO074': 'NO54'
 }

# %%
uk_shape["center"] = uk_shape["geometry"].centroid
uk_shape["rep"] = uk_shape["geometry"].representative_point()
points_uk = uk_shape.copy()
points_uk.set_geometry("center", inplace = True)
# Out:
# /tmp/ipykernel_41466/3688001849.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   uk_shape["center"] = uk_shape["geometry"].centroid

# %%
sweden = gpd.read_file('data/shapes/sweden.geojson').query("countryName == 'Sweden'").assign(
    zone = lambda x : x.zoneName.str[-3:]
).rename(
    columns={'zone' : 'index'}
).set_index(
    'index'
).drop(
    columns={'zoneName','countryKey','countryName'}
)

# %%
sweden['center'] = sweden['geometry'].centroid
sweden['rep'] = sweden['geometry'].representative_point()
points_se = sweden.copy()
points_se.set_geometry('center',inplace = True)
points_se = points_se.reset_index()
# Out:
# /tmp/ipykernel_41466/4116756702.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   sweden['center'] = sweden['geometry'].centroid

# %%
uk_shape = gpd.read_file('data/shapes/uk_base.shp')
uk_shape = uk_shape.replace(
    {
        'Name_1' : {
            'Z1_1':'UK1',
            'Z1_2' : 'UK2',
            'Z1_3' : 'UK2',
            'Z1_4' : 'UK2',
            'Z2' : 'UK2',
            'Z3' : 'UK3',
            'Z4' : 'UK3',
            'Z5' : 'UK3',
            'Z6' : 'UK3',
            'Z7' : 'UK4',
            'Z8' : 'UK4',
            'Z9' : 'UK5',
            'Z10' : 'UK4',
            'Z11' : 'UK6',
            'Z12' : 'UK7',
            'Z13' : 'UK8',
            'Z14' : 'UK7',
            'Z15' : 'UK7',
            'Z16' : 'UK7',
            'Z17' : 'UK8',
        }
    }
)
uk_shape = uk_shape.to_crs("EPSG:4326")
uk_shape = uk_shape.dissolve(by='Name_1', aggfunc='sum').reset_index()
uk_shape = uk_shape.replace({'NI' : 'UK9'})

# %%
uk_shape
# Out:
#   Name_1                                           geometry  OBJECTID_1  \
# 0    UK9  MULTIPOLYGON (((-7.25757 55.05069, -7.24179 55...          55
# 1    UK1  MULTIPOLYGON (((-1.59675 59.53205, -1.61339 59...           9
# 2    UK2  MULTIPOLYGON (((-6.25321 56.49285, -6.24202 56...          26
# 3    UK3  MULTIPOLYGON (((-6.07905 55.78147, -6.06391 55...          19
# 4    UK4  POLYGON ((0.16781 53.46453, 0.17090 53.45704, ...          39
# 5    UK5  MULTIPOLYGON (((-4.17781 53.29757, -4.15490 53...          45
# 6    UK6  POLYGON ((-0.09334 52.66085, -0.79626 52.03332...          17
# 7    UK7  MULTIPOLYGON (((-1.11952 50.73419, -1.10911 50...          51
# 8    UK8  MULTIPOLYGON (((-2.02196 49.22549, -2.01732 49...         145
#
#    OBJECTID    Shape_Leng          Area  NEAR_FID  NEAR_DIST    Shape_Le_1  \
# 0        31  8.317939e+05      0.000000         0        0.0  8.323488e+05
# 1         9  8.088063e+05   1361.004852       201        0.0  8.088063e+05
# ...

# %%
uk_shape["center"] = uk_shape["geometry"].centroid
uk_shape["rep"] = uk_shape["geometry"].representative_point()
points_uk = uk_shape.copy()
points_uk.set_geometry("center", inplace = True)
# Out:
# /tmp/ipykernel_41466/3688001849.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   uk_shape["center"] = uk_shape["geometry"].centroid

# %%
highRES_zones = pd.read_csv('zones.csv')

# %%
shape_lvl3 = gpd.read_file(
    'NUTS_RG_10M_2021_4326.geojson',
    crs = "EPSG:4326"
)

shape_lvl3 = shape_lvl3.loc[shape_lvl3['LEVL_CODE'] == 3]

# %%
shape_lvl3 = shape_lvl3[shape_lvl3.CNTR_CODE.str.contains('NO')].query('FID != "NO0B1" and FID != "NO0B2"')
shape_lvl3 = shape_lvl3.replace({
 'NO081': 'NO03',
 'NO082': 'NO30',
 'NO020': 'NO34',
 'NO091': 'NO38',
 'NO092': 'NO42',
 'NO0A1': 'NO11',
 'NO0A2': 'NO46',
 'NO0A3': 'NO15',
 'NO060': 'NO50',
 'NO071': 'NO18',
 'NO074': 'NO54'
 }
)
shape_lvl3["center"] = shape_lvl3["geometry"].centroid
shape_lvl3["rep"] = shape_lvl3["geometry"].representative_point()
points_norway = shape_lvl3.copy()
points_norway.set_geometry("center", inplace = True)
# Out:
# /tmp/ipykernel_41466/1909695715.py:16: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   shape_lvl3["center"] = shape_lvl3["geometry"].centroid

# %%
shape_lvl3
# Out:
#         id NUTS_ID  LEVL_CODE CNTR_CODE             NAME_LATN  \
# 1029  NO03    NO03          3        NO                  Oslo
# 1030  NO30    NO30          3        NO                 Viken
# 1031  NO34    NO34          3        NO             Innlandet
# 1032  NO38    NO38          3        NO  Vestfold og Telemark
# 1033  NO42    NO42          3        NO                 Agder
# 1048  NO18    NO18          3        NO              Nordland
# 1053  NO54    NO54          3        NO     Troms og Finnmark
# 1107  NO11    NO11          3        NO              Rogaland
# 1136  NO46    NO46          3        NO              Vestland
# 1137  NO15    NO15          3        NO       Møre og Romsdal
# 2003  NO50    NO50          3        NO             Trøndelag
#
#                  NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE   FID  \
# 1029                  Oslo         3.0          1           1  NO03
# 1030                 Viken         2.0          2           1  NO30
# ...

# %%
points_norway
# Out:
#         id NUTS_ID  LEVL_CODE CNTR_CODE             NAME_LATN  \
# 1029  NO03    NO03          3        NO                  Oslo
# 1030  NO30    NO30          3        NO                 Viken
# 1031  NO34    NO34          3        NO             Innlandet
# 1032  NO38    NO38          3        NO  Vestfold og Telemark
# 1033  NO42    NO42          3        NO                 Agder
# 1048  NO18    NO18          3        NO              Nordland
# 1053  NO54    NO54          3        NO     Troms og Finnmark
# 1107  NO11    NO11          3        NO              Rogaland
# 1136  NO46    NO46          3        NO              Vestland
# 1137  NO15    NO15          3        NO       Møre og Romsdal
# 2003  NO50    NO50          3        NO             Trøndelag
#
#                  NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE   FID  \
# 1029                  Oslo         3.0          1           1  NO03
# 1030                 Viken         2.0          2           1  NO30
# ...

# %%
points_norway = points_norway.assign(
    x_coord = lambda x: x.center.x,
    y_coord = lambda x: x.center.y
)

#points_norway.at[1, 'x_coord'] = 3.5 # Belgium
#gdf_cap_plot.at[1, 'y_coord'] = 50.64

# %%
points_norway.at[1030,'x_coord'] = 8.73
points_norway.at[1032,'y_coord'] = 59.2
points_norway.at[1033,'x_coord'] = 7.5
points_norway.at[1033,'y_coord'] = 58.3
points_norway.at[1107,'x_coord'] = 5.4
points_norway.at[1136,'x_coord'] = 5.4

# %%
points_norway.set_geometry(gpd.points_from_xy(points_norway.x_coord, points_norway.y_coord, crs="EPSG:4326"),inplace=True)

# %%
points_norway
# Out:
#         id NUTS_ID  LEVL_CODE CNTR_CODE             NAME_LATN  \
# 1029  NO03    NO03          3        NO                  Oslo
# 1030  NO30    NO30          3        NO                 Viken
# 1031  NO34    NO34          3        NO             Innlandet
# 1032  NO38    NO38          3        NO  Vestfold og Telemark
# 1033  NO42    NO42          3        NO                 Agder
# 1048  NO18    NO18          3        NO              Nordland
# 1053  NO54    NO54          3        NO     Troms og Finnmark
# 1107  NO11    NO11          3        NO              Rogaland
# 1136  NO46    NO46          3        NO              Vestland
# 1137  NO15    NO15          3        NO       Møre og Romsdal
# 2003  NO50    NO50          3        NO             Trøndelag
#
#                  NUTS_NAME  MOUNT_TYPE  URBN_TYPE  COAST_TYPE   FID  \
# 1029                  Oslo         3.0          1           1  NO03
# 1030                 Viken         2.0          2           1  NO30
# ...

# %%
# Processed file. Does not contain e.g. Luxembourg
#shape_europe = gpd.read_file(
#    'NUTS_RG_10M_2021_4326_europe_LEVL_0.geojson',
#    crs = "EPSG:4326"
#)

# %%
shape_europe = gpd.read_file(
    'NUTS_RG_10M_2021_4326.geojson',
    crs = "EPSG:4326"
)

# %%
shape_europe = shape_europe.loc[shape_europe['LEVL_CODE'] == 0]

# %%
highRES_shape = shape_europe.copy()
highRES_shape = highRES_shape.replace({
    'EL' : 'GR'
}
)

# %%
highRES_shape
# Out:
#       id NUTS_ID  LEVL_CODE CNTR_CODE                NAME_LATN  \
# 1901  AL      AL          0        AL                Shqipëria
# 1902  AT      AT          0        AT               Österreich
# 1903  BE      BE          0        BE          Belgique/België
# 1916  DK      DK          0        DK                  Danmark
# 1920  DE      DE          0        DE              Deutschland
# 1930  NL      NL          0        NL                Nederland
# 1931  PL      PL          0        PL                   Polska
# 1932  PT      PT          0        PT                 Portugal
# 1934  UK      UK          0        UK           United Kingdom
# 1936  TR      TR          0        TR                  Türkiye
# 1941  ES      ES          0        ES                   España
# 1951  BG      BG          0        BG                 Bulgaria
# 1952  CH      CH          0        CH  Schweiz/Suisse/Svizzera
# 1953  CY      CY          0        CY                   Kýpros
# ...

# %%
highRES_shape = highRES_shape[highRES_shape['id'].isin(highRES_zones.zone)]

# %%
highRES_shape["center"] = highRES_shape["geometry"].centroid
highRES_shape["rep"] = highRES_shape["geometry"].representative_point()
points_europe = highRES_shape.copy()
points_europe.set_geometry("rep", inplace = True)
# Out:
# /tmp/ipykernel_41466/309292076.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   highRES_shape["center"] = highRES_shape["geometry"].centroid
# /home/oskar/miniconda3/envs/oskar/lib/python3.10/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/oskar/miniconda3/envs/oskar/lib/python3.10/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
fig, ax = plt.subplots(figsize = (20,20))

# Europe without Norway and UK
highRES_shape.plot(
    ax = ax,
    color = "whitesmoke", 
    edgecolor = "lightgrey", 
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_europe.geometry.x, points_europe.geometry.y, points_europe["id"]):
    texts.append(plt.text(x, y, label, fontsize = 12))

# Norway
shape_lvl3.plot(
    ax = ax,
    color = 'rosybrown',
    edgecolor = 'lightgrey',
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_norway.geometry.x, points_norway.geometry.y, points_norway["NUTS_ID"]):
    texts.append(plt.text(x, y, label, fontsize = 12))
    
# UK
uk_shape.plot(
    ax = ax,
    color = 'rosybrown',
    edgecolor = 'lightgrey',
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_uk.geometry.x, points_uk.geometry.y, points_uk["Name_1"]):
    texts.append(plt.text(x, y, label, fontsize = 12))

# Sweden
sweden.plot(
    ax = ax,
    color = 'rosybrown',
    edgecolor = 'lightgrey',
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_se.geometry.x, points_se.geometry.y, points_se['index']):
    texts.append(plt.text(x, y, label, fontsize = 12))
    
plt.xlim([-12,32])
plt.ylim([33,72])

#plt.savefig('country_overview.pdf',bbox_inches='tight')

# %% [markdown]
# # With Transmission

# %% [markdown]
# We want to merge:
# * highRES_shape
# * shape_lvl3
# * uk_shape

# %%
uk_shape_mod = uk_shape.copy().drop(
    columns={
        'OBJECTID',
        'OBJECTID_1',
        'Shape_Leng',
        'Area',
        'NEAR_FID',
        'Shape_Le_1',
        'Shape_Area',
        'NEAR_DIST'
    }
).rename(
    columns={
        'Name_1' : 'id'
    }
)

# %%
highRES_shape_coords = highRES_shape.append(shape_lvl3).drop(
    columns={
        'NUTS_ID',
        'LEVL_CODE',
        'CNTR_CODE',
        'NAME_LATN',
        'NUTS_NAME',
        'MOUNT_TYPE',
        'URBN_TYPE',
        'COAST_TYPE',
        'FID'
    }
).append(uk_shape_mod).append(sweden.reset_index().rename(columns={'index' : 'id'}))
# Out:
# /tmp/ipykernel_41466/2878886683.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   highRES_shape_coords = highRES_shape.append(shape_lvl3).drop(
# /tmp/ipykernel_41466/2878886683.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ).append(uk_shape_mod).append(sweden.reset_index().rename(columns={'index' : 'id'}))
# /tmp/ipykernel_41466/2878886683.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ).append(uk_shape_mod).append(sweden.reset_index().rename(columns={'index' : 'id'}))

# %%
highRES_shape_coords
# Out:
#         id                                           geometry  \
# 1902    AT  POLYGON ((15.54245 48.90770, 15.75363 48.85218...
# 1903    BE  POLYGON ((5.10218 51.42900, 5.08780 51.38230, ...
# 1916    DK  MULTIPOLYGON (((14.82540 55.25410, 14.94371 55...
# 1920    DE  MULTIPOLYGON (((9.42015 54.83196, 9.42293 54.8...
# 1930    NL  MULTIPOLYGON (((6.87491 53.40801, 6.91836 53.3...
# 1931    PL  MULTIPOLYGON (((18.95003 54.35831, 19.35966 54...
# 1932    PT  MULTIPOLYGON (((-8.16508 41.81830, -8.05186 41...
# 1941    ES  MULTIPOLYGON (((4.28746 39.82237, 4.24593 39.8...
# 1951    BG  POLYGON ((22.99717 43.80787, 23.25146 43.83394...
# 1952    CH  POLYGON ((8.67046 47.68486, 8.79571 47.67560, ...
# 1966    RO  POLYGON ((27.39117 47.58940, 27.44355 47.53666...
# 1968    CZ  POLYGON ((14.31787 51.05470, 14.41509 51.02507...
# 1969    FI  MULTIPOLYGON (((28.92968 69.05190, 28.45147 68...
# 1970    EE  MULTIPOLYGON (((25.83016 59.56406, 25.88224 59...
# ...

# %%
highRES_shape_coords = highRES_shape_coords.assign(
    x_coord_center = lambda x: x.center.x,
    y_coord_center = lambda x: x.center.y,
    x_coord_rep = lambda x: x.rep.x,
    y_coord_rep = lambda x: x.rep.y
)#.sort_values("NUTS_ID").reset_index()

# %%
highRES_shape_coords
# Out:
#         id                                           geometry  \
# 1902    AT  POLYGON ((15.54245 48.90770, 15.75363 48.85218...
# 1903    BE  POLYGON ((5.10218 51.42900, 5.08780 51.38230, ...
# 1916    DK  MULTIPOLYGON (((14.82540 55.25410, 14.94371 55...
# 1920    DE  MULTIPOLYGON (((9.42015 54.83196, 9.42293 54.8...
# 1930    NL  MULTIPOLYGON (((6.87491 53.40801, 6.91836 53.3...
# 1931    PL  MULTIPOLYGON (((18.95003 54.35831, 19.35966 54...
# 1932    PT  MULTIPOLYGON (((-8.16508 41.81830, -8.05186 41...
# 1941    ES  MULTIPOLYGON (((4.28746 39.82237, 4.24593 39.8...
# 1951    BG  POLYGON ((22.99717 43.80787, 23.25146 43.83394...
# 1952    CH  POLYGON ((8.67046 47.68486, 8.79571 47.67560, ...
# 1966    RO  POLYGON ((27.39117 47.58940, 27.44355 47.53666...
# 1968    CZ  POLYGON ((14.31787 51.05470, 14.41509 51.02507...
# 1969    FI  MULTIPOLYGON (((28.92968 69.05190, 28.45147 68...
# 1970    EE  MULTIPOLYGON (((25.83016 59.56406, 25.88224 59...
# ...

# %%
df_trans = pd.read_csv('data/transmission_lines.tsv', sep = "\t")

# %%
df_trans
# Out:
#    Zone1 Zone2        Tech
# 0     AT    HU   HVAC400KV
# 1     AT    CZ   HVAC400KV
# 2     AT    CH   HVAC400KV
# 3     AT    DE   HVAC400KV
# 4     AT    SI   HVAC400KV
# ..   ...   ...         ...
# 93   UK9    IE   HVAC400KV
# 94   UK9   UK3  HVDCSubsea
# 95   SE1   SE2   HVAC400KV
# 96   SE2   SE3   HVAC400KV
# 97   SE3   SE4   HVAC400KV
#
# [98 rows x 3 columns]

# %%
df_trans_overhead = df_trans.loc[df_trans['Tech'] == "HVAC400KV"]
df_trans_subsea = df_trans.loc[df_trans['Tech'] == "HVDCSubsea"]#.reset_index(drop=True)

# %%
pd.options.mode.chained_assignment = None  # default='warn'

df_trans_overhead['x1_coord'] = None
df_trans_overhead['y1_coord'] = None
df_trans_overhead['x2_coord'] = None
df_trans_overhead['y2_coord'] = None

for i in range(len(df_trans_overhead.index)):
    df_trans_overhead.x1_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_overhead.Zone1.iloc[i]].x_coord_rep.to_numpy()[0]
    df_trans_overhead.y1_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_overhead.Zone1.iloc[i]].y_coord_rep.to_numpy()[0]
    df_trans_overhead.x2_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_overhead.Zone2.iloc[i]].x_coord_rep.to_numpy()[0]
    df_trans_overhead.y2_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_overhead.Zone2.iloc[i]].y_coord_rep.to_numpy()[0]

# %%
pd.options.mode.chained_assignment = None  # default='warn'

df_trans_subsea['x1_coord'] = None
df_trans_subsea['y1_coord'] = None
df_trans_subsea['x2_coord'] = None
df_trans_subsea['y2_coord'] = None

for i in range(len(df_trans_subsea.index)):
    df_trans_subsea.x1_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_subsea.Zone1.iloc[i]].x_coord_rep.to_numpy()[0]
    df_trans_subsea.y1_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_subsea.Zone1.iloc[i]].y_coord_rep.to_numpy()[0]
    df_trans_subsea.x2_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_subsea.Zone2.iloc[i]].x_coord_rep.to_numpy()[0]
    df_trans_subsea.y2_coord.iloc[i] = highRES_shape_coords.loc[highRES_shape_coords['id'] == df_trans_subsea.Zone2.iloc[i]].y_coord_rep.to_numpy()[0]

# %%
df_trans_subsea
# Out:
#    Zone1 Zone2        Tech   x1_coord   y1_coord   x2_coord   y2_coord
# 10    BE   UK7  HVDCSubsea   4.881817   50.50927   0.083227    51.8527
# 19    DE   SE4  HVDCSubsea  10.504506   51.09207  14.431447  56.437087
# 25    DE   UK7  HVDCSubsea  10.504506   51.09207   0.083227    51.8527
# 26    DE  NO42  HVDCSubsea  10.504506   51.09207   7.877382  58.827075
# 27    DK   SE3  HVDCSubsea   9.250172   56.24825  15.088892  59.525364
# 29    DK   UK4  HVDCSubsea   9.250172   56.24825   -1.18172  54.146043
# 30    DK  NO42  HVDCSubsea   9.250172   56.24825   7.877382  58.827075
# 35    ES   UK8  HVDCSubsea  -3.469213  39.891725   -2.49453  51.210698
# 37    FI   SE3  HVDCSubsea  27.459304   64.94007  15.088892  59.525364
# 40    FR    IE  HVDCSubsea   2.187452  46.727085  -8.109445  53.440925
# 41    FR   UK7  HVDCSubsea   2.187452  46.727085   0.083227    51.8527
# 42    GR    IT  HVDCSubsea   21.81675  39.084475  12.674732   42.50005
# ...

# %%
fig, ax = plt.subplots(figsize = (20,20))

# Europe without Norway and UK
highRES_shape.plot(
    ax = ax,
    color = "whitesmoke", 
    edgecolor = "lightgrey", 
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_europe.geometry.x, points_europe.geometry.y, points_europe["id"]):
    texts.append(plt.text(x, y, label, fontsize = 12))

# Norway
shape_lvl3.plot(
    ax = ax,
    color = 'rosybrown',
    edgecolor = 'lightgrey',
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_norway.geometry.x, points_norway.geometry.y, points_norway["NUTS_ID"]):
    texts.append(plt.text(x, y, label, fontsize = 12))
    
# UK

uk_shape.plot(
    ax = ax,
    color = 'rosybrown',
    edgecolor = 'lightgrey',
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_uk.geometry.x, points_uk.geometry.y, points_uk["Name_1"]):
    texts.append(plt.text(x, y, label, fontsize = 12))

# Sweden
sweden.plot(
    ax = ax,
    color = 'rosybrown',
    edgecolor = 'lightgrey',
    linewidth = 0.5
)

texts = []

for x, y, label in zip(points_se.geometry.x, points_se.geometry.y, points_se['index']):
    texts.append(plt.text(x, y, label, fontsize = 12))
    
# plot overhead cables
for i in range(len(df_trans_overhead.index)):
    plt.plot(
        [df_trans_overhead.x1_coord.iloc[i],df_trans_overhead.x2_coord.iloc[i]],
        [df_trans_overhead.y1_coord.iloc[i],df_trans_overhead.y2_coord.iloc[i]],
        '#009E73',
        linewidth = 2,
        alpha = 0.5
    )  

#plot subsea cables
for i in range(len(df_trans_subsea.index)):
    plt.plot(
        [df_trans_subsea.x1_coord.iloc[i],df_trans_subsea.x2_coord.iloc[i]],
        [df_trans_subsea.y1_coord.iloc[i],df_trans_subsea.y2_coord.iloc[i]],
        '#E69F00',
        linewidth = 2,
        alpha = 1,
    )      
    
    
ax.set_axis_off()
plt.xlim([-12,32])
plt.ylim([33,72])

plt.plot()

overhead = mpatches.Patch(color='#009E73', label='Overhead transmission')
subsea = mpatches.Patch(color='#E69F00', label='Subsea transmission')
plt.legend(handles=[overhead,subsea],loc="center right")

plt.savefig('figures/transmission_lines_highRES.pdf',bbox_inches='tight')

# %% [markdown]
# ## Distance between nodes

# %%
dist_df = highRES_shape.copy().drop(
    columns={
        'NUTS_ID',
        'LEVL_CODE',
        'CNTR_CODE',
        'NAME_LATN',
        'NUTS_NAME',
        'MOUNT_TYPE',
        'URBN_TYPE',
        'COAST_TYPE',
        'FID',
        'center',
        'rep'
    }
)#.to_crs('EPSG:3035')

# %%
uk_shape_new = uk_shape.rename(columns={'Name_1' : 'id'}).drop(
    columns={
        'OBJECTID_1',
        'OBJECTID',
        'Shape_Leng',
        'Area',
        'NEAR_FID',
        'NEAR_DIST',
        'Shape_Le_1',
        'Shape_Area',
        'center',
        'rep'
    }
)

# %%
NO_new = shape_lvl3.drop(
    columns={
        'NUTS_ID',
        'LEVL_CODE',
        'CNTR_CODE',
        'NAME_LATN',
        'NUTS_NAME',
        'MOUNT_TYPE',
        'URBN_TYPE',
        'COAST_TYPE',
        'FID',
        'center',
        'rep'
    }
)

# %%
merged_df = dist_df.append(uk_shape_new).append(NO_new).append(sweden.reset_index().rename(columns={'index' : 'id'}).drop(columns={'rep'})).to_crs("EPSG:3035")
# Out:
# /tmp/ipykernel_41466/2411994166.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = dist_df.append(uk_shape_new).append(NO_new).append(sweden.reset_index().rename(columns={'index' : 'id'}).drop(columns={'rep'})).to_crs("EPSG:3035")
# /tmp/ipykernel_41466/2411994166.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = dist_df.append(uk_shape_new).append(NO_new).append(sweden.reset_index().rename(columns={'index' : 'id'}).drop(columns={'rep'})).to_crs("EPSG:3035")
# /tmp/ipykernel_41466/2411994166.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
merged_df["center"] = merged_df["geometry"].centroid

# %%
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#       id                                           geometry  \
# 0     AT  POLYGON ((4726983.652 2881333.529, 4742889.099...
# 1     BE  POLYGON ((3980658.876 3157887.669, 3979312.981...
# 2     DK  MULTIPOLYGON (((4627718.684 3582386.027, 46355...
# 3     DE  MULTIPOLYGON (((4283725.165 3525289.358, 42838...
# 4     NL  MULTIPOLYGON (((4113226.651 3371154.602, 41158...
# 5     PL  MULTIPOLYGON (((4901276.764 3508415.412, 49274...
# 6     PT  MULTIPOLYGON (((2822605.079 2261162.917, 28317...
# 7     ES  MULTIPOLYGON (((3829784.273 1877307.326, 38261...
# 8     BG  POLYGON ((5363358.561 2390534.724, 5383031.368...
# 9     CH  POLYGON ((4221123.396 2731035.643, 4230515.051...
# 10    RO  POLYGON ((5616141.742 2872864.610, 5621291.789...
# 11    CZ  POLYGON ((4623549.852 3113763.529, 4630550.464...
# 12    FI  MULTIPOLYGON (((5073773.587 5207017.965, 50597...
# 13    EE  MULTIPOLYGON (((5209290.523 4151085.770, 52109...
# 14    HU  POLYGON ((5214660.279 2880853.697, 5216710.449...
# ...

# %%
round(merged_df.iloc[46,2].distance(merged_df.iloc[45,2])/1000,1)
# Out:
# 304.7

# %%
merged_df.assign(dist_norway = lambda x : x.center.distance(merged_df.iloc[32,2]))
# Out:
#       id                                           geometry  \
# 0     AT  POLYGON ((4726983.652 2881333.529, 4742889.099...
# 1     BE  POLYGON ((3980658.876 3157887.669, 3979312.981...
# 2     DK  MULTIPOLYGON (((4627718.684 3582386.027, 46355...
# 3     DE  MULTIPOLYGON (((4283725.165 3525289.358, 42838...
# 4     NL  MULTIPOLYGON (((4113226.651 3371154.602, 41158...
# 5     PL  MULTIPOLYGON (((4901276.764 3508415.412, 49274...
# 6     PT  MULTIPOLYGON (((2822605.079 2261162.917, 28317...
# 7     ES  MULTIPOLYGON (((3829784.273 1877307.326, 38261...
# 8     BG  POLYGON ((5363358.561 2390534.724, 5383031.368...
# 9     CH  POLYGON ((4221123.396 2731035.643, 4230515.051...
# 10    RO  POLYGON ((5616141.742 2872864.610, 5621291.789...
# 11    CZ  POLYGON ((4623549.852 3113763.529, 4630550.464...
# 12    FI  MULTIPOLYGON (((5073773.587 5207017.965, 50597...
# 13    EE  MULTIPOLYGON (((5209290.523 4151085.770, 52109...
# 14    HU  POLYGON ((5214660.279 2880853.697, 5216710.449...
# ...

# %%
temp = shape_europe.to_crs("EPSG:3035")

# %%
temp["center"] = temp["geometry"].centroid
temp = temp.reset_index(drop=True)
